# %% [markdown]
# Consumindo os dados que foram enviados para o BigQuery

# %% [markdown]
# Importando bibliotecas

# %%
import pandas as pd
from google.cloud import bigquery

# %% [markdown]
# cliente

# %%
client = bigquery.Client.from_service_account_json('C:/Users/ninem/Documents/storied-parser-332511-082bf009d3ff.json')

# %% [markdown]
# ID da tabela no Biguery

# %%
table = "storied-parser-332511.General.enderecos"

# %%
# montando a consulta. Vamos retornar todas as colunas da tabela
query = f"SELECT * FROM `{table}`"

# %% [markdown]
# Executando a consulta

# %%
df = client.query(query).to_dataframe()
# Out:
# c:\Users\ninem\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %% [markdown]
# Exibindo os valores retornados

# %%
print(df.head())
# Out:
#          cep                     logradouro          bairro          cidade  \
# 0  70714-020    Quadra SCN Quadra 4 Bloco B       Asa Norte        Brasília
# 1  20050-000        Rua Alexandre Herculano          Centro  Rio de Janeiro
# 2  01153-000           Rua Vitorino Carmilo     Barra Funda       São Paulo
# 3  13214-661        Avenida Caetano Gornati    Engordadouro         Jundiaí
# 4  05778-180  Rua Caio Graco da Silva Prado  Parque Arariba       São Paulo
#
#   estado
# 0     DF
# 1     RJ
# 2     SP
# 3     SP
# 4     SP
